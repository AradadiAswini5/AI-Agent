# %% [markdown]
# FOOD ORDERING AI AGENT
#
# Understand the user’s food request
# Decide what food fits best
# Choose best restaurant
# Place the order (simulated)
# Return final confirmation
#
# Overview:
# Client (Web/App)
#    ↓
# API Gateway (FastAPI)
#    ↓
# Auth & Rate Limiting
#    ↓
# LangGraph Controller
#    ↓
# Agent A (Planner)
#    ↓
# Agent B (Executor)
#    ↓
# Agent C (Verifier)
#    ↓
# Database / APIs
#    ↓
# Response

# %%
# !pip install langgraph langchain langchain-community
# Out:
# Requirement already satisfied: langgraph in c:\anaconda\envs\agenticai\lib\site-packages (1.0.5)
# Requirement already satisfied: langchain in c:\anaconda\envs\agenticai\lib\site-packages (1.2.0)
# Requirement already satisfied: langchain-community in c:\anaconda\envs\agenticai\lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-core>=0.1 in c:\anaconda\envs\agenticai\lib\site-packages (from langgraph) (1.2.5)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\anaconda\envs\agenticai\lib\site-packages (from langgraph) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\anaconda\envs\agenticai\lib\site-packages (from langgraph) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\anaconda\envs\agenticai\lib\site-packages (from langgraph) (0.3.1)
# Requirement already satisfied: pydantic>=2.7.4 in c:\anaconda\envs\agenticai\lib\site-packages (from langgraph) (2.11.10)
# Requirement already satisfied: xxhash>=3.5.0 in c:\anaconda\envs\agenticai\lib\site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\anaconda\envs\agenticai\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph) (1.12.1)
# Requirement already satisfied: httpx>=0.25.2 in c:\anaconda\envs\agenticai\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\anaconda\envs\agenticai\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\anaconda\envs\agenticai\lib\site-packages (from langchain-core>=0.1->langgraph) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\anaconda\envs\agenticai\lib\site-packages (from langchain-core>=0.1->langgraph) (0.5.1)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\anaconda\envs\agenticai\lib\site-packages (from langchain-core>=0.1->langgraph) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\anaconda\envs\agenticai\lib\site-packages (from langchain-core>=0.1->langgraph) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\anaconda\envs\agenticai\lib\site-packages (from langchain-core>=0.1->langgraph) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\anaconda\envs\agenticai\lib\site-packages (from langchain-core>=0.1->langgraph) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\anaconda\envs\agenticai\lib\site-packages (from langchain-core>=0.1->langgraph) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\anaconda\envs\agenticai\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.1->langgraph) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\anaconda\envs\agenticai\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\anaconda\envs\agenticai\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\anaconda\envs\agenticai\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (0.25.0)
# Requirement already satisfied: anyio in c:\anaconda\envs\agenticai\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (4.10.0)
# Requirement already satisfied: certifi in c:\anaconda\envs\agenticai\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\anaconda\envs\agenticai\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.0.9)
# Requirement already satisfied: idna in c:\anaconda\envs\agenticai\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\anaconda\envs\agenticai\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\anaconda\envs\agenticai\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\anaconda\envs\agenticai\lib\site-packages (from pydantic>=2.7.4->langgraph) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\anaconda\envs\agenticai\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\anaconda\envs\agenticai\lib\site-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\anaconda\envs\agenticai\lib\site-packages (from langchain-community) (2.0.45)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\anaconda\envs\agenticai\lib\site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\anaconda\envs\agenticai\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\anaconda\envs\agenticai\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\anaconda\envs\agenticai\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in c:\anaconda\envs\agenticai\lib\site-packages (from langchain-community) (2.2.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\anaconda\envs\agenticai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\anaconda\envs\agenticai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\anaconda\envs\agenticai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\anaconda\envs\agenticai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\anaconda\envs\agenticai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\anaconda\envs\agenticai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\anaconda\envs\agenticai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\anaconda\envs\agenticai\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\anaconda\envs\agenticai\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in c:\anaconda\envs\agenticai\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\anaconda\envs\agenticai\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\anaconda\envs\agenticai\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda\envs\agenticai\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.5.0)
# Requirement already satisfied: greenlet>=1 in c:\anaconda\envs\agenticai\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\anaconda\envs\agenticai\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in c:\anaconda\envs\agenticai\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.3.1)

# %%
from langgraph.graph import StateGraph
from typing import TypedDict, List

# %%
#define agent state

class OrderState(TypedDict):
    user_input: str
    menu: list
    selected_item: dict
    final_response: str

# %%
#define menu

MENU = [
    {"item": "Veg Burger", "price": 199},
    {"item": "Cheese Pizza", "price": 299},
    {"item": "Pasta", "price": 249},
    {"item": "Veg Biryani", "price": 229}
]

# %%
#define agent nodes

#planner node
def planner(state: OrderState):
    return {
        "user_input": state["user_input"],
        "menu": MENU
    }


#selector node
def select_food(state: OrderState):
    # Choose cheapest item
    cheapest = min(state["menu"], key=lambda x: x["price"])
    return {"selected_item": cheapest}

# %%
#Final Response Node

def finalize_order(state: OrderState):
    item = state["selected_item"]
    return {
        "final_response": f"""
🍽️ Order Confirmed!

Item: {item['item']}
Price: ₹{item['price']}

Thank you for ordering!
"""
    }

# %%
#Build LangGraph

from langgraph.graph import StateGraph

graph = StateGraph(OrderState)

graph.add_node("planner", planner)
graph.add_node("selector", select_food)
graph.add_node("final", finalize_order)

graph.set_entry_point("planner")
graph.add_edge("planner", "selector")
graph.add_edge("selector", "final")

app = graph.compile()

# %%
result = app.invoke({"user_input": "I want something cheap to eat"})
print(result["final_response"])
# Out:
# 🍽️ Order Confirmed!
#
# Item: Veg Burger
# Price: ₹199
#
# Thank you for ordering!

# %% [markdown]
# Planner + Researcher + Critic using LangChain + GROQ

# %% [markdown]
# MULTI-AGENT TRAVEL ASSISTANT (FLIGHT BOOKING)
# 🧠 What this agent will do
#
# User says:
#
# “Book the cheapest flight from Chennai to Delhi tomorrow.”
#
# The system will:
#
# 🧠 Planner Agent → decides steps
#
# 🔍 Researcher Agent → decides what info is needed
#
# ⚙️ Executor Agent → fetches flights, selects cheapest, books
#
# 🧐 Critic Agent → verifies booking details
#
# ✅ Includes real-world actions (API simulation + file saving)
#
# | Agent         | Role                                       |
# | ------------- | ------------------------------------------ |
# | 🧠 Planner    | Break booking task into steps              |
# | 🔍 Researcher | Decide data needed (routes, dates, prices) |
# | ⚙️ Executor   | Call flight APIs & book                    |
# | 🧐 Critic     | Verify booking correctness                 |

# %%
# !pip install langchain langchain-groq sentence-transformers faiss-cpu
# Out:
# Requirement already satisfied: langchain in c:\anaconda\envs\agenticai\lib\site-packages (1.2.0)
# Requirement already satisfied: langchain-groq in c:\anaconda\envs\agenticai\lib\site-packages (1.1.1)
# Requirement already satisfied: sentence-transformers in c:\anaconda\envs\agenticai\lib\site-packages (5.2.0)
# Requirement already satisfied: faiss-cpu in c:\anaconda\envs\agenticai\lib\site-packages (1.13.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.1 in c:\anaconda\envs\agenticai\lib\site-packages (from langchain) (1.2.5)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\anaconda\envs\agenticai\lib\site-packages (from langchain) (1.0.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\anaconda\envs\agenticai\lib\site-packages (from langchain) (2.11.10)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\anaconda\envs\agenticai\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\anaconda\envs\agenticai\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (0.5.1)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\anaconda\envs\agenticai\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\anaconda\envs\agenticai\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\anaconda\envs\agenticai\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\anaconda\envs\agenticai\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\anaconda\envs\agenticai\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\anaconda\envs\agenticai\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.1->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\anaconda\envs\agenticai\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\anaconda\envs\agenticai\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\anaconda\envs\agenticai\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.3.1)
# Requirement already satisfied: xxhash>=3.5.0 in c:\anaconda\envs\agenticai\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\anaconda\envs\agenticai\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.1)
# Requirement already satisfied: httpx>=0.25.2 in c:\anaconda\envs\agenticai\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\anaconda\envs\agenticai\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\anaconda\envs\agenticai\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\anaconda\envs\agenticai\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\anaconda\envs\agenticai\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\anaconda\envs\agenticai\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (4.10.0)
# Requirement already satisfied: certifi in c:\anaconda\envs\agenticai\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\anaconda\envs\agenticai\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\anaconda\envs\agenticai\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\anaconda\envs\agenticai\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\anaconda\envs\agenticai\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\anaconda\envs\agenticai\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\anaconda\envs\agenticai\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: groq<1.0.0,>=0.30.0 in c:\anaconda\envs\agenticai\lib\site-packages (from langchain-groq) (0.37.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\anaconda\envs\agenticai\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: sniffio in c:\anaconda\envs\agenticai\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.3.1)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\anaconda\envs\agenticai\lib\site-packages (from sentence-transformers) (4.57.3)
# Requirement already satisfied: tqdm in c:\anaconda\envs\agenticai\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\anaconda\envs\agenticai\lib\site-packages (from sentence-transformers) (2.9.1)
# Requirement already satisfied: scikit-learn in c:\anaconda\envs\agenticai\lib\site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy in c:\anaconda\envs\agenticai\lib\site-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\anaconda\envs\agenticai\lib\site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: filelock in c:\anaconda\envs\agenticai\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in c:\anaconda\envs\agenticai\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2.2.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\anaconda\envs\agenticai\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\anaconda\envs\agenticai\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\anaconda\envs\agenticai\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\anaconda\envs\agenticai\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.12.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\anaconda\envs\agenticai\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda\envs\agenticai\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (2.5.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\anaconda\envs\agenticai\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\anaconda\envs\agenticai\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in c:\anaconda\envs\agenticai\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\anaconda\envs\agenticai\lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\anaconda\envs\agenticai\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\anaconda\envs\agenticai\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\anaconda\envs\agenticai\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: joblib>=1.3.0 in c:\anaconda\envs\agenticai\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\anaconda\envs\agenticai\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)

# %%
import os
os.environ["GROQ_API_KEY"] = "key"

# %%
#import required modules

from langchain_groq import ChatGroq
from langchain_core.messages import HumanMessage, SystemMessage

# %%
#Create the LLM (Shared by All Agents)

llm = ChatGroq(
    model="llama-3.1-8b-instant",
    temperature=0
)

# %%
#REAL-WORLD TOOLS (SIMULATED FLIGHT APIs)

def fetch_flights(source, destination, date):
    return [
        {"flight": "IndiGo 6E-203", "price": 5200, "time": "06:00"},
        {"flight": "Air India AI-441", "price": 6100, "time": "09:30"},
        {"flight": "Vistara UK-835", "price": 5800, "time": "14:00"}
    ]

# %%
#Tool 2: Book flight (REAL ACTION)

def book_flight(flight_details):
    booking = f"""
Flight Booked Successfully ✈️
Flight: {flight_details['flight']}
Price: ₹{flight_details['price']}
Departure Time: {flight_details['time']}
"""
    with open("flight_booking.txt", "w", encoding="utf-8") as f:
        f.write(booking)
    return booking

# %%
#Planner Agent

def planner_agent(task):
    messages = [
        SystemMessage(content="You are a travel planner. Break the task into steps."),
        HumanMessage(content=task)
    ]
    return llm.invoke(messages).content

# %%
#Researcher Agent

def researcher_agent(plan):
    messages = [
        SystemMessage(content="You are a travel researcher. Identify required flight data."),
        HumanMessage(content=plan)
    ]
    return llm.invoke(messages).content

# %%
#Executor Agent

def executor_agent():
    flights = fetch_flights("Chennai", "Delhi", "Tomorrow")

    cheapest = min(flights, key=lambda x: x["price"])

    booking_confirmation = book_flight(cheapest)
    return booking_confirmation

# %%
#Critic Agent

def critic_agent(booking_output):
    messages = [
        SystemMessage(content="You are a critic. Verify booking details and clarity."),
        HumanMessage(content=booking_output)
    ]
    return llm.invoke(messages).content

# %%
#Orchestrator (Multi-Agent Controller)

def travel_booking_agent(user_query):
    print("🧠 Planner Agent\n")
    plan = planner_agent(user_query)
    print(plan)

    print("\n🔍 Researcher Agent\n")
    research = researcher_agent(plan)
    print(research)

    print("\n⚙️ Executor Agent (Booking Flight)\n")
    booking = executor_agent()
    print(booking)

    print("\n🧐 Critic Agent\n")
    final = critic_agent(booking)
    print(final)

    return final

# %%
travel_booking_agent(
    "Book the cheapest flight from Chennai to Delhi tomorrow"
)
# Out:
# 🧠 Planner Agent
#
# To book the cheapest flight from Chennai to Delhi tomorrow, I'll follow these steps:
#
# **Step 1: Research and Compare Prices**
#
# * I'll use flight comparison websites such as Skyscanner, Google Flights, or Kayak to find the cheapest flights from Chennai to Delhi.
# * I'll also check the airlines' official websites, such as Air India, IndiGo, or SpiceJet, to see if they have any promotions or discounts.
#
# **Step 2: Check Flight Availability**
#
# * I'll check the flight schedules for tomorrow and see which flights are available.
# * I'll also check for any layovers or connections, as these can sometimes be cheaper than non-stop flights.
#
# **Step 3: Filter Results**
#
# * I'll filter the results to show only the cheapest flights, and then sort them by price.
# * I'll also consider factors such as flight duration, departure and arrival times, and airline reputation.
#
# **Step 4: Book the Flight**
#
# * Once I've found the cheapest flight, I'll book it online using the airline's website or a flight comparison website.
# * I'll make sure to read and agree to the airline's terms and conditions, including any baggage fees or other charges.
#
# **Step 5: Confirm the Booking**
#
# * After booking the flight, I'll receive a confirmation email with the flight details, including the flight number, departure and arrival times, and any other important information.
# * I'll also make sure to check the airline's website for any updates or changes to the flight schedule.
#
# Here's an example of what the booking process might look like:
#
# * Flight: IndiGo 6E 123 from Chennai to Delhi
# * Departure: Tomorrow, 10:00 AM
# * Arrival: Tomorrow, 12:30 PM
# * Price: ₹ 4,500
# * Booking Status: Confirmed
#
# Please note that prices and availability may vary depending on the time of booking and other factors.
#
# 🔍 Researcher Agent
#
# To book the cheapest flight from Chennai to Delhi tomorrow, I'll need the following flight data:
#
# 1. **Departure City**: Chennai
# 2. **Destination City**: Delhi
# 3. **Travel Date**: Tomorrow
# 4. **Flight Class**: Economy (assuming cheapest option)
# 5. **Flight Number**: Not specified, will be obtained from flight comparison websites or airlines' official websites
# 6. **Departure Time**: Not specified, will be obtained from flight comparison websites or airlines' official websites
# 7. **Arrival Time**: Not specified, will be obtained from flight comparison websites or airlines' official websites
# 8. **Airline**: IndiGo, Air India, SpiceJet, or other airlines operating on this route
# 9. **Price**: ₹ 4,500 (or the cheapest available price)
# 10. **Booking Status**: Confirmed (once the booking is made)
#
# Additionally, I'll need to consider the following factors:
#
# 1. **Flight Schedules**: Availability of flights tomorrow
# 2. **Layovers or Connections**: Presence of layovers or connections, if any
# 3. **Flight Duration**: Duration of the flight
# 4. **Departure and Arrival Times**: Specific departure and arrival times
# 5. **Airline Reputation**: Reputation of the airline operating the flight
#
# To obtain the required flight data, I'll use flight comparison websites such as Skyscanner, Google Flights, or Kayak, as well as the airlines' official websites.
#
# ⚙️ Executor Agent (Booking Flight)
#
#
# Flight Booked Successfully ✈️
# Flight: IndiGo 6E-203
# Price: ₹5200
# Departure Time: 06:00
#
#
# 🧐 Critic Agent
#
# To verify the booking details, I would like to clarify a few points:
#
# 1. **Flight Number and Airline**: The flight number is 6E-203, which is operated by IndiGo. This seems correct.
# 2. **Price**: The price of the ticket is ₹5200. I would like to confirm if this includes any additional fees, taxes, or charges.
# 3. **Departure Time**: The departure time is 06:00. I would like to confirm if this is the local time at the departure airport or the scheduled time in the destination's local time.
# 4. **Flight Details**: I would like to confirm the flight's origin, destination, and any layovers or connections.
#
# To ensure clarity, could you please provide the following information:
#
# - Origin airport code
# - Destination airport code
# - Any layovers or connections
# - Check-in and baggage policies
# - Cancellation and refund policies
#
# This will help me verify the booking details and provide a more accurate assessment.
# "To verify the booking details, I would like to clarify a few points:\n\n1. **Flight Number and Airline**: The flight number is 6E-203, which is operated by IndiGo. This seems correct.\n2. **Price**: The price of the ticket is ₹5200. I would like to confirm if this includes any additional fees, taxes, or charges.\n3. **Departure Time**: The departure time is 06:00. I would like to confirm if this is the local time at the departure airport or the scheduled time in the destination's local time.\n4. **Flight Details**: I would like to confirm the flight's origin, destination, and any layovers or connections.\n\nTo ensure clarity, could you please provide the following information:\n\n- Origin airport code\n- Destination airport code\n- Any layovers or connections\n- Check-in and baggage policies\n- Cancellation and refund policies\n\nThis will help me verify the booking details and provide a more accurate assessment."
